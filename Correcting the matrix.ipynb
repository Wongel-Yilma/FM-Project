# %%
import numpy as np

# %%
mat = np.load("C:\\Users\\USU-CMM\\data54.npy")

# %%
mat
# Out:
# array([[5.0000e+07, 9.0000e-03, 4.0000e-03, 9.2803e+06],
#        [5.0000e+07, 9.0000e-03, 5.0000e-03, 8.7332e+06],
#        [5.0000e+07, 9.0000e-03, 6.0000e-03, 8.4250e+06],
#        [5.0000e+07, 1.0000e-02, 4.0000e-03, 1.0084e+07],
#        [5.0000e+07, 1.0000e-02, 5.0000e-03, 9.6191e+06],
#        [5.0000e+07, 1.0000e-02, 6.0000e-03, 9.6516e+06],
#        [5.0000e+07, 1.1000e-02, 4.0000e-03, 1.1097e+07],
#        [5.0000e+07, 1.1000e-02, 5.0000e-03, 1.0504e+07],
#        [5.0000e+07, 1.1000e-02, 6.0000e-03, 1.0604e+07],
#        [1.0000e+08, 9.0000e-03, 4.0000e-03, 1.8561e+07],
#        [1.0000e+08, 9.0000e-03, 5.0000e-03, 1.7466e+07],
#        [1.0000e+08, 9.0000e-03, 6.0000e-03, 1.6850e+07],
#        [1.0000e+08, 1.0000e-02, 4.0000e-03, 2.0169e+07],
#        [1.0000e+08, 1.0000e-02, 5.0000e-03, 1.9238e+07],
#        [1.0000e+08, 1.0000e-02, 6.0000e-03, 1.9303e+07],
#        [1.0000e+08, 1.1000e-02, 4.0000e-03, 2.2194e+07],
# ...

# %%
for i in range(len(mat)):
    Area= 0.005*mat[i,2]
    Force = mat[i,0]*Area
    mat[i,0] = Force

# %%
mat
# Out:
# array([[1.0000e+03, 9.0000e-03, 4.0000e-03, 9.2803e+06],
#        [1.2500e+03, 9.0000e-03, 5.0000e-03, 8.7332e+06],
#        [1.5000e+03, 9.0000e-03, 6.0000e-03, 8.4250e+06],
#        [1.0000e+03, 1.0000e-02, 4.0000e-03, 1.0084e+07],
#        [1.2500e+03, 1.0000e-02, 5.0000e-03, 9.6191e+06],
#        [1.5000e+03, 1.0000e-02, 6.0000e-03, 9.6516e+06],
#        [1.0000e+03, 1.1000e-02, 4.0000e-03, 1.1097e+07],
#        [1.2500e+03, 1.1000e-02, 5.0000e-03, 1.0504e+07],
#        [1.5000e+03, 1.1000e-02, 6.0000e-03, 1.0604e+07],
#        [2.0000e+03, 9.0000e-03, 4.0000e-03, 1.8561e+07],
#        [2.5000e+03, 9.0000e-03, 5.0000e-03, 1.7466e+07],
#        [3.0000e+03, 9.0000e-03, 6.0000e-03, 1.6850e+07],
#        [2.0000e+03, 1.0000e-02, 4.0000e-03, 2.0169e+07],
#        [2.5000e+03, 1.0000e-02, 5.0000e-03, 1.9238e+07],
#        [3.0000e+03, 1.0000e-02, 6.0000e-03, 1.9303e+07],
#        [2.0000e+03, 1.1000e-02, 4.0000e-03, 2.2194e+07],
# ...

# %%
np.save('data54Updated.npy',data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 np.save('data54Updated.npy',data)
#
# NameError: name 'data' is not defined
